# %%
#藉由首頁取得所有文章的URL
import requests
from bs4 import BeautifulSoup
import json

test = open("spider/pet/test.txt","w",encoding='UTF-8')


p = requests.Session()
url=requests.get("https://www.dcard.tw/f/pet")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.PostList_wrapper_2BLUM a.PostEntry_root_V6g0r")
a=[]
for s in sel:
    a.append(s["href"])
url = "https://www.dcard.tw"+ a[2]

for k in range(0,10):
        post_data={
            "before":a[-1][9:18],
            "limit":"30",
            "popular":"true"
        }
        r = p.get("https://www.dcard.tw/_api/forums/pet/posts",params=post_data, headers = { "Referer": "https://www.dcard.tw/", "User-Agent": "Mozilla/5.0" })
        data2 = json.loads(r.text)
        for u in range(len(data2)):
            Temporary_url = "/f/pet/p/"+ str(data2[u]["id"]) + "-" + str(data2[u]["title"].replace(" ","-"))
            a.append(Temporary_url)
j=0
q=0
for i in a[2:]:
    url = "https://www.dcard.tw"+i
    j+=1
    print ("第",j,"頁的URL為:"+url)
    #file.write("temperature is {} wet is {}%\n".format(temperature, humidity))
    test.write("第 {} 頁的URL為: {} \n".format(j,url))
    url=requests.get(url)
    soup = BeautifulSoup(url.text,"html.parser")
    sel_jpg = soup.select("div.Post_content_NKEl9 div div div img.GalleryImage_image_3lGzO")
    for c in sel_jpg:
        q+=1
        print("第",q,"張:",c["src"])
        test.write("%\n""第 {} 張: {} \n".format(q,c["src"])) 
        pic=requests.get(c["src"])
        img2 = pic.content
        pic_out = open("spider/pet/"+str(q)+".png",'wb')
        pic_out.write(img2)
        pic_out.close()

test.close()
print("爬蟲結束")
# Out:
# 第 1 頁的URL為:https://www.dcard.tw/f/pet/p/229840996-＃虎斑-有看過那麼肉的貓嗎？
# 第 1 張: https://imgur.dcard.tw/iGS1Y59.jpg
# 第 2 張: https://imgur.dcard.tw/3qC7JDN.jpg
# 第 3 張: https://imgur.dcard.tw/uXpTVL8.jpg
# 第 2 頁的URL為:https://www.dcard.tw/f/pet/p/229842897-睡姿很像人的貓😂
# 第 4 張: https://imgur.dcard.tw/WdKKepS.jpg
# 第 5 張: https://imgur.dcard.tw/2rjGiPn.jpg
# 第 6 張: https://imgur.dcard.tw/Gs66RHL.jpg
# 第 3 頁的URL為:https://www.dcard.tw/f/pet/p/229846342-＃柴-兩個月小白柴
# 第 7 張: https://imgur.dcard.tw/rfHgncK.jpg
# 第 8 張: https://imgur.dcard.tw/9hiRfnb.jpg
# 第 9 張: https://imgur.dcard.tw/DKNZQmY.jpg
# 第 10 張: https://imgur.dcard.tw/do3BzUY.jpg
# 第 11 張: https://imgur.dcard.tw/IIhxq20.jpg
# 第 12 張: https://imgur.dcard.tw/3nD1Qu7.jpg
# 第 13 張: https://imgur.dcard.tw/aHkTXFd.jpg
# 第 14 張: https://imgur.dcard.tw/8uHkrvU.jpg
# 第 15 張: https://imgur.dcard.tw/JrZ4lsO.jpg
# 第 16 張: https://imgur.dcard.tw/AmJGmLI.jpg
# 第 17 張: https://imgur.dcard.tw/xudkcyh.jpg
# 第 18 張: https://imgur.dcard.tw/MQJhhu5.jpg
# 第 19 張: https://imgur.dcard.tw/Gnzuqqn.jpg
# 第 103 張: https://imgur.dcard.tw/SmH8XsH.jpg
# 第 104 張: https://imgur.dcard.tw/MzY0uR9.jpg
# 第 105 張: https://imgur.dcard.tw/yoA2vCc.jpg
# 第 106 張: https://imgur.dcard.tw/kvRwVSx.jpg
# 第 107 張: https://imgur.dcard.tw/6Y7y3Nn.jpg
# 第 108 張: https://imgur.dcard.tw/g7YDOsu.jpg
# 第 109 張: https://imgur.dcard.tw/NVdELap.jpg
# 第 110 張: https://imgur.dcard.tw/7njCyuh.jpg
# 第 111 張: https://imgur.dcard.tw/8NrmKdg.jpg
# 第 112 張: https://imgur.dcard.tw/Qrt8xSI.jpg
# 第 113 張: https://imgur.dcard.tw/C6Jo4BT.jpg
# 第 114 張: https://imgur.dcard.tw/FpHqaHd.jpg
# 第 115 張: https://imgur.dcard.tw/h5SN0uv.jpg
# 第 116 張: https://imgur.dcard.tw/35GxmYb.jpg
# 第 117 張: https://imgur.dcard.tw/Pst7iBe.jpg
# 第 118 張: https://imgur.dcard.tw/RAwSDBb.jpg
# 第 119 張: https://imgur.dcard.tw/Zw6XOc6.jpg
# 第 120 張: https://imgur.dcard.tw/MdcrabX.jpg
# 第 121 張: https://imgur.dcard.tw/4ejVqJ3.jpg
# 第 122 張: https://imgur.dcard.tw/YEXDit3.jpg
# 第 123 張: https://imgur.dcard.tw/ns6inln.jpg
# 第 124 張: https://imgur.dcard.tw/xNjdWtz.jpg
# 第 125 張: https://imgur.dcard.tw/xDrUxJ5.jpg
# 第 126 張: https://imgur.dcard.tw/xbxcIlu.jpg
# 第 127 張: https://imgur.dcard.tw/9ayKcWT.jpg
# 第 128 張: https://imgur.dcard.tw/vxB5mpt.jpg
# 第 129 張: https://imgur.dcard.tw/wO05zy0.jpg
# 第 130 張: https://imgur.dcard.tw/PSgT80y.jpg
# 第 131 張: https://imgur.dcard.tw/iUrbEcm.jpg
# 第 132 張: //i.imgur.com/YF5cOuu.jpg
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-2-dbce015ec4dc> in <module>
#      42         print("第",q,"張:",c["src"])
#      43         test.write("%\n""第 {} 張: {} \n".format(q,c["src"]))
# ---> 44         pic=requests.get(c["src"])
#      45         img2 = pic.content
#      46         pic_out = open("spider/pet/"+str(q)+".png",'wb')
#
# d:\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# d:\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# d:\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     496             hooks=hooks,
#     497         )
# --> 498         prep = self.prepare_request(req)
#     499
#     500         proxies = proxies or {}
#
# d:\python\python36\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     439             auth=merge_setting(auth, self.auth),
#     440             cookies=merged_cookies,
# --> 441             hooks=merge_hooks(request.hooks, self.hooks),
#     442         )
#     443         return p
#
# d:\python\python36\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     307
#     308         self.prepare_method(method)
# --> 309         self.prepare_url(url, params)
#     310         self.prepare_headers(headers)
#     311         self.prepare_cookies(cookies)
#
# d:\python\python36\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     381             error = error.format(to_native_string(url, 'utf8'))
#     382
# --> 383             raise MissingSchema(error)
#     384
#     385         if not host:
#
# MissingSchema: Invalid URL '//i.imgur.com/YF5cOuu.jpg': No schema supplied. Perhaps you meant http:////i.imgur.com/YF5cOuu.jpg?
