# %% [markdown]
# # 抓取標題

# %%
import requests
from bs4 import BeautifulSoup
url=requests.get("https://www.dcard.tw/f/sex")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.PostEntry_content_g2afg h3")
for s in sel:
    print(s.text)
# Out:
# #必看 禁止在西斯版用任何形式交換聯絡資料
# #更 看板功能相關說明＆重要提醒
# 研究所學妹
# #圖 上班犯規
# #圖 服裝的重要
# #圖 #更新 不聽話
# #圖多 #肉 一個月只做愛一次
# 淫蕩👩🏻‍💼👩🏻‍💼👩🏻‍💼
# #圖 洗澡自慰☺️
# 想女友
# 嘿，我是班
# #圖 噗滋噗滋水做の女子
# #吞噬我的哥斯拉
# #圖 遠距離的小情趣
# #文長😨#圖 一次性愛，讓我見識到原來自己可以這麼乾。
# #腿/高跟鞋 愛上被舔腳的快感
# 突然好想要
# #圖 第一次3P體驗-兩男一女
# 想把你吃掉🤤
# #影 推薦 喜歡無碼的 笑起來超漂亮 真的是素人嗎
# #影片 又流出 怎麼最近一堆流出 正義魔人不要來
# #圖 主人的手
# 是我太傻才被騙 😪😪
# 一下子就高潮了...
# 如果不想成為裸照或自拍影片的男/女主角
# #圖 第一次調教
# 當個有理性的西斯人
# 放假要幹嘛
# #無碼流出#有片 佐藤遙希最新步兵片(30分54秒)~
# 主人不在家很寂寞

# %% [markdown]
# # 將每一頁URL寫入list
# a --> 首頁全部標題
# a[3] -->第一頁的url

# %%
import requests
from bs4 import BeautifulSoup
url=requests.get("https://www.dcard.tw/f/sex")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.PostList_wrapper_2BLUM a.PostEntry_root_V6g0r")
a=[]
for s in sel:
    print(s["href"])
    a.append(s["href"])
print(a[2])
print(len(a))
# Out:
# /f/sex/p/59114-＃必看-禁止在西斯版用任何形式交換聯絡資料
# /f/sex/p/228960046-＃更-看板功能相關說明＆重要提醒
# /f/sex/p/229815063-研究所學妹
# /f/sex/p/229818809-＃圖-上班犯規
# /f/sex/p/229814346-＃圖-服裝的重要
# /f/sex/p/229814661-＃圖-＃更新-不聽話
# /f/sex/p/229818216-＃圖多-＃肉-一個月只做愛一次
# /f/sex/p/229817894-淫蕩👩🏻💼👩🏻💼👩🏻💼
# /f/sex/p/229819065-＃圖-洗澡自慰☺️
# /f/sex/p/229820050-想女友
# /f/sex/p/229820331-嘿，我是班
# /f/sex/p/229818175-＃圖-噗滋噗滋水做の女子
# /f/sex/p/229816588-＃吞噬我的哥斯拉
# /f/sex/p/229818646-＃圖-遠距離的小情趣
# /f/sex/p/229815457-＃文長😨＃圖-一次性愛，讓我見識到原來自己可以這麼乾。
# /f/sex/p/229816351-＃腿／高跟鞋-愛上被舔腳的快感
# /f/sex/p/229819540-突然好想要
# /f/sex/p/229819902-＃圖-第一次3P體驗-兩男一女
# /f/sex/p/229816921-＃影-推薦-喜歡無碼的-笑起來超漂亮-真的是素人嗎
# /f/sex/p/229820058-想把你吃掉🤤
# /f/sex/p/229817340-＃影片-又流出-怎麼最近一堆流出-正義魔人不要來
# /f/sex/p/229816770-＃圖-主人的手
# /f/sex/p/229818288-是我太傻才被騙-😪😪
# /f/sex/p/229817749-一下子就高潮了...
# /f/sex/p/229820549-如果不想成為裸照或自拍影片的男／女主角
# /f/sex/p/229821374-＃圖-第一次調教
# /f/sex/p/229818051-當個有理性的西斯人
# /f/sex/p/229821372-放假要幹嘛
# /f/sex/p/229816828-主人不在家很寂寞
# /f/sex/p/229816841-＃無碼流出＃有片-佐藤遙希最新步兵片（30分54秒）~
# /f/sex/p/229815063-研究所學妹
# 30

# %% [markdown]
# # 印出確實的URL

# %%
import requests
from bs4 import BeautifulSoup
url=requests.get("https://www.dcard.tw/f/sex")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.PostList_wrapper_2BLUM a.PostEntry_root_V6g0r")
a=[]
for s in sel:
    a.append(s["href"])
url = "https://www.dcard.tw"+ a[2]
j=0
for i in a[2:]:
    url = "https://www.dcard.tw"+i
    j+=1
    print ("第",j,"頁的URL為:"+url)
# Out:
# 第 1 頁的URL為:https://www.dcard.tw/f/sex/p/229815063-研究所學妹
# 第 2 頁的URL為:https://www.dcard.tw/f/sex/p/229818809-＃圖-上班犯規
# 第 3 頁的URL為:https://www.dcard.tw/f/sex/p/229814346-＃圖-服裝的重要
# 第 4 頁的URL為:https://www.dcard.tw/f/sex/p/229814661-＃圖-＃更新-不聽話
# 第 5 頁的URL為:https://www.dcard.tw/f/sex/p/229818216-＃圖多-＃肉-一個月只做愛一次
# 第 6 頁的URL為:https://www.dcard.tw/f/sex/p/229817894-淫蕩👩🏻💼👩🏻💼👩🏻💼
# 第 7 頁的URL為:https://www.dcard.tw/f/sex/p/229819065-＃圖-洗澡自慰☺️
# 第 8 頁的URL為:https://www.dcard.tw/f/sex/p/229820050-想女友
# 第 9 頁的URL為:https://www.dcard.tw/f/sex/p/229820331-嘿，我是班
# 第 10 頁的URL為:https://www.dcard.tw/f/sex/p/229818175-＃圖-噗滋噗滋水做の女子
# 第 11 頁的URL為:https://www.dcard.tw/f/sex/p/229816588-＃吞噬我的哥斯拉
# 第 12 頁的URL為:https://www.dcard.tw/f/sex/p/229818646-＃圖-遠距離的小情趣
# 第 13 頁的URL為:https://www.dcard.tw/f/sex/p/229815457-＃文長😨＃圖-一次性愛，讓我見識到原來自己可以這麼乾。
# 第 14 頁的URL為:https://www.dcard.tw/f/sex/p/229816351-＃腿／高跟鞋-愛上被舔腳的快感
# 第 15 頁的URL為:https://www.dcard.tw/f/sex/p/229819540-突然好想要
# 第 16 頁的URL為:https://www.dcard.tw/f/sex/p/229819902-＃圖-第一次3P體驗-兩男一女
# 第 17 頁的URL為:https://www.dcard.tw/f/sex/p/229816921-＃影-推薦-喜歡無碼的-笑起來超漂亮-真的是素人嗎
# 第 18 頁的URL為:https://www.dcard.tw/f/sex/p/229820058-想把你吃掉🤤
# 第 19 頁的URL為:https://www.dcard.tw/f/sex/p/229817340-＃影片-又流出-怎麼最近一堆流出-正義魔人不要來
# 第 20 頁的URL為:https://www.dcard.tw/f/sex/p/229816770-＃圖-主人的手
# 第 21 頁的URL為:https://www.dcard.tw/f/sex/p/229818288-是我太傻才被騙-😪😪
# 第 22 頁的URL為:https://www.dcard.tw/f/sex/p/229817749-一下子就高潮了...
# 第 23 頁的URL為:https://www.dcard.tw/f/sex/p/229820549-如果不想成為裸照或自拍影片的男／女主角
# 第 24 頁的URL為:https://www.dcard.tw/f/sex/p/229821374-＃圖-第一次調教
# 第 25 頁的URL為:https://www.dcard.tw/f/sex/p/229818051-當個有理性的西斯人
# 第 26 頁的URL為:https://www.dcard.tw/f/sex/p/229821372-放假要幹嘛
# 第 27 頁的URL為:https://www.dcard.tw/f/sex/p/229816828-主人不在家很寂寞
# 第 28 頁的URL為:https://www.dcard.tw/f/sex/p/229816841-＃無碼流出＃有片-佐藤遙希最新步兵片（30分54秒）~

# %% [markdown]
# # 抓某一頁的全部圖片

# %%
import requests
from bs4 import BeautifulSoup

url=requests.get("https://www.dcard.tw/f/sex/p/229815063-%E7%A0%94%E7%A9%B6%E6%89%80%E5%AD%B8%E5%A6%B9")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.Post_content_NKEl9 div div div img.GalleryImage_image_3lGzO")
for s in sel:
    print(s["src"])
    pic=requests.get(s["src"])
    img2 = pic.content
    pic_out = open("parser/"+str(s["src"][23:]),'wb')
    pic_out.write(img2)
    pic_out.close()
# Out:
# https://imgur.dcard.tw/p3VZwvR.jpg
# https://imgur.dcard.tw/wwIwU2Z.jpg
# https://imgur.dcard.tw/f7xwIC8.jpg

# %% [markdown]
# # 完成版

# %%
import requests
from bs4 import BeautifulSoup
url=requests.get("https://www.dcard.tw/f/sex")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.PostList_wrapper_2BLUM a.PostEntry_root_V6g0r")
a=[]
for s in sel:
    a.append(s["href"])
url = "https://www.dcard.tw"+ a[2]
j=0
q=0
for i in a[2:]:
    url = "https://www.dcard.tw"+i
    j+=1
    print ("第",j,"頁的URL為:"+url)
    url=requests.get(url)
    soup = BeautifulSoup(url.text,"html.parser")
    sel_jpg = soup.select("div.Post_content_NKEl9 div div div img.GalleryImage_image_3lGzO")
    for c in sel_jpg:
        q+=1
        print("第",q,"張:",c["src"])
        pic=requests.get(c["src"])
        img2 = pic.content
        pic_out = open("spider/sex/"+str(c["src"][23:]),'wb')
        pic_out.write(img2)
        pic_out.close()
# Out:
# 第 1 頁的URL為:https://www.dcard.tw/f/sex/p/229815063-研究所學妹
# 第 1 張: https://imgur.dcard.tw/p3VZwvR.jpg
# 第 2 張: https://imgur.dcard.tw/wwIwU2Z.jpg
# 第 3 張: https://imgur.dcard.tw/f7xwIC8.jpg
# 第 2 頁的URL為:https://www.dcard.tw/f/sex/p/229818809-＃圖-上班犯規
# 第 4 張: https://imgur.dcard.tw/r7BVp95.jpg
